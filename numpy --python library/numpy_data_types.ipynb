# %%
import numpy as np

# %%
arr = np.array([2,3,4,56,7,8,9,1,2,2],dtype = 'int32')
arr
# Out:
# array([ 2,  3,  4, 56,  7,  8,  9,  1,  2,  2], dtype=int32)

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr.nbytes
# Out:
# 40

# %%
array =np.array([2j*2j],dtype = 'complex128')

# %%
array
# Out:
# array([-4.+0.j])
