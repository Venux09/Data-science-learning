# %%
import numpy as np #numpy library of the python

# %%
#doing the speed check of the python list compreshension vs python numpy library

# %%
#checking the speed of the numpy the python library

# %%
l1 = [1,2,3]

# %%
l2 = [6,7,8]

# %%
list(zip(l1,l2))
# Out:
# [(1, 6), (2, 7), (3, 8)]
