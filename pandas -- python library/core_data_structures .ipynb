# %%
import pandas as pd

# %%
s = pd.Series([34,56,7,87,98,97,76,45,67])#this is the method of pandas which arrange the numbers in series 
s
# Out:
# 0    34
# 1    56
# 2     7
# 3    87
# 4    98
# 5    97
# 6    76
# 7    45
# 8    67
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#by using this indexing method we can set our own index of the values 
s = pd.Series([34,56,7,87,98,97],index = ['monu','shubh','simran','himesh','rudransh','aloosingh'])
s
# Out:
# monu         34
# shubh        56
# simran        7
# himesh       87
# rudransh     98
# aloosingh    97
# dtype: int64

# %%
s['monu']#by doing this we can get the certain value at certain index
# Out:
# np.int64(34)

# %%
int(s['himesh'])
# Out:
# 87

# %%
#data frame is the method of the pandas which is like a dictonary which contains many seiries 
data = {
"name": ["Monu verma", "Bob", "Charlie"],
"age": [17, 30, 35],
"city": ["haryana--Faridabad", "Mumbai", "Bangalore"]
}
d = pd.DataFrame(data)
d
# Out:
#          name  age                city
# 0  Monu verma   17  haryana--Faridabad
# 1         Bob   30              Mumbai
# 2     Charlie   35           Bangalore

# %%
d.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
d.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
d.index = [1,2,3]

# %%
d.index
# Out:
# Index([1, 2, 3], dtype='int64')

# %%
d
# Out:
#          name  age                city
# 1  Monu verma   17  haryana--Faridabad
# 2         Bob   30              Mumbai
# 3     Charlie   35           Bangalore

# %%
d.var
# Out:
# <bound method DataFrame.var of          name  age                city
# 1  Monu verma   17  haryana--Faridabad
# 2         Bob   30              Mumbai
# 3     Charlie   35           Bangalore>

# %%
d
# Out:
#          name  age                city
# 1  Monu verma   17  haryana--Faridabad
# 2         Bob   30              Mumbai
# 3     Charlie   35           Bangalore

# %%
d.index
# Out:
# Index([1, 2, 3], dtype='int64')

# %%
d.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
d.columns  = ['Name','Age','City']

# %%
d
# Out:
#          Name  Age                City
# 1  Monu verma   17  haryana--Faridabad
# 2         Bob   30              Mumbai
# 3     Charlie   35           Bangalore
