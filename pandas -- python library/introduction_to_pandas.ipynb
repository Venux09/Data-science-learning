# %%
#pandas is open source python library which is used for data analyisis , data manipulatio and data cleaning ..
#it is more faster and more presentable than python functions.

# %%
#it represents the data in the form like sql and excel so it is useful there also

# %%
import pandas as pd
