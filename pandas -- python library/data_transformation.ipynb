# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#for sorting the numbers 
df.sort_values("Year",ascending = False)#using false statement for the gettingthe decreadsed oreder data
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#using the normal sorting methode 
df2 = df.sort_values(["IMDb",'Year']).copy()#position of the condition you are giving also matter if you  give some condition better then other than it is going to be considered
#postion matter

# %%
df2#now problem is that it is showing that indexing is not lloking good in the sense you know what i am saying here
# Out:
#                  Actor                      Film  Year            Genre  \
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#reseting the index to make it in right pattern
df2.reset_index(drop= True,inplace = True)#using the drop = True so it is  not going to show the old index which it was showing recentily when we were seeing when we rnnded the fucntion recentioly

# %%
#using inplace = True is a method update the orgiginal data it applies in most of the function in pandas
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2          Salman Khan           Tiger Zinda Hai  2017           Action
# 3         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4       Hrithik Roshan                       War  2019           Action
# 5        Ranveer Singh                 Padmaavat  2018       Historical
# 6         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Shah Rukh Khan                   Pathaan  2023           Action
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 10  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2          Salman Khan           Tiger Zinda Hai  2017           Action
# 3         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4       Hrithik Roshan                       War  2019           Action
# 5        Ranveer Singh                 Padmaavat  2018       Historical
# 6         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Shah Rukh Khan                   Pathaan  2023           Action
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 10  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#here rank make a new column and rank the imdb as bigger it is it will get bigger rank but if you will use the False methode it is going to give you opposite value and method dense help giving the integer rank 
df2["rank"] = df2["IMDb"].rank(ascending= False,method= 'dense')

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2          Salman Khan           Tiger Zinda Hai  2017           Action
# 3         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4       Hrithik Roshan                       War  2019           Action
# 5        Ranveer Singh                 Padmaavat  2018       Historical
# 6         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Shah Rukh Khan                   Pathaan  2023           Action
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 10  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
df = df[["Genre","Actor","Year","IMDb","Film","BoxOffice(INR Crore)"]]
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2          Salman Khan           Tiger Zinda Hai  2017           Action
# 3         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4       Hrithik Roshan                       War  2019           Action
# 5        Ranveer Singh                 Padmaavat  2018       Historical
# 6         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Shah Rukh Khan                   Pathaan  2023           Action
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 10  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11          Aamir Khan                    Dangal  2016        Biography
#
# ...

# %%
col = ["Actor"]+[col for col in df.columns if col != "Actor"]
df = df[col]
df
# Out:
#                  Actor            Genre  Year  IMDb                      Film  \
# 0       Shah Rukh Khan           Action  2023   7.2                   Pathaan
# 1          Salman Khan           Action  2017   6.0           Tiger Zinda Hai
# 2           Aamir Khan        Biography  2016   8.4                    Dangal
# 3        Ranbir Kapoor          Fantasy  2022   5.6                Brahmastra
# 4        Ranveer Singh       Historical  2018   7.0                 Padmaavat
# 5   Ayushmann Khurrana         Thriller  2018   8.3                 Andhadhun
# 6        Rajkummar Rao    Horror Comedy  2018   7.5                     Stree
# 7       Hrithik Roshan           Action  2019   6.5                       War
# 8         Akshay Kumar           Comedy  2019   7.0                Good Newwz
# 9        Kartik Aaryan    Horror Comedy  2022   5.9         Bhool Bhulaiyaa 2
# 10        Varun Dhawan  Romantic Comedy  2017   6.1     Badrinath Ki Dulhania
# ...
