# %%
a = 10
b= 5

# %%
a+b
# Out:
# 15

# %%
a*b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
#when number is divided by something it becomes decimal aka float

# %%
2**5
# Out:
# 32

# %%
10**10
# Out:
# 10000000000

# %%
a = 45

# %%
b = 4

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
-a>b
# Out:
# False

# %%
-(a)<b
# Out:
# True

# %%
a!= b
# Out:
# True

# %%
a = 5
print(a!)
# Out:
#   Cell In[16], line 2
#     print(a!)
#            ^
# SyntaxError: invalid syntax

# %%
print(a+5)
# Out:
# 50

# %%
c = 5

# %%
c+= 4

# %%
c
# Out:
# 9

# %%
c-=4

# %%
c
# Out:
# 5

# %%
c/= 4

# %%
c
# Out:
# 1.25

# %%
c //= 4

# %%
c
# Out:
# 0.0
