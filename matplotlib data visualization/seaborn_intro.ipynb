# %%
#introduction to the seadborn

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
sns.set_theme(style='darkgrid')

# %%
x = np.array([1,2,3,4,55,5,66,66,7,7,3,54,5,45,45,435,345,346,35,653,63454,54,5,24,52,5343,43])
y = np.cos(x)
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
