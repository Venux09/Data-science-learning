# %%
#here wer are going to study about the probability of tosing 100 coins at the same time and knowing what is the p
#what is probabilty of getting a right answer

# %%
from scipy.stats import binom

# %%
# n = no of the chances 
# k = success 
# p = probabily of getting that thing

# %%
prob = binom.pmf(k = 10 , n = 11 , p = 0.5)
print(f"this is the probabilty of getting a set of coins which have 10 heads in 11 coins tossing {int{prob}}")
# Out:
# this is the probabilty of getting a set of coins which have 10 heads in 11 coins tossing int0.00537109375
