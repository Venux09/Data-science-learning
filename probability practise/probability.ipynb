# %%
# here we are going to practise with probability methods

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
random = np.random.uniform(0,1,1000)
plt.hist(radom , bins = 50 , dnesty = True, color = 'blue',alpha = 0.6) 
plt.title('the uniform continuous data in between 0 to 1 ')
plt.xlable('value')
plt.ylable('probabibilty density')
plt.grid(True)
plt.legent(True)
plt.show()
