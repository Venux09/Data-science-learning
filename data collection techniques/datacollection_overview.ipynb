# %%
#now we are gonna understand the data collections techniques

# %%
#we have to consider many things also

# %%
#there are different ways of data collection

# %%
#api , python library,and internet

# %%
#always do ethical consideration
