# %%
with open("initial.txt", encoding = 'utf-8') as f :
    data = f.read()

# %%
chunks = data.split('\n\n')#divides the data where there is some data with splits like \n\n
chunks = [c for c in chunks if len(c)>5]
chunks[4]
# Out:
# 'silkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants'

# %%
def parse_chunk(chunk):
    try:
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split(" posts")[0].replace(",","").replace(" post",""))
        no_of_followers = float(sep_chunk[2].split(" followers")[0].replace(",","").replace("K","").replace("m",""))
        if ("k" in sep_chunk[2]):
            no_of_followers = int(no_of_followers*1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers*1000000)
            

        no_of_following = int(sep_chunk[3].split(" following")[0].replace(",",""))
        name = sep_chunk[4]
        if  (len(sep_chunk))>5:#for solving the problem the types of pages error and bio error for like every profile doesnot have bio and posts
            types_of_pages = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            types_of_pages = "unknown"
            bio = ""
            
        # print(username,no_of_follower,no_of_following,no_of_posts,name,types_of_pages,bio,sep="\n")
        return {"username":username,"no_of_followers":no_of_followers,"no_of_following":no_of_following,
                "no_of_posts":no_of_posts,"name":name,"types_of_pages":types_of_pages,"bio":bio}
    except Exception  as e:
        print(e,chunk)
# parse_chunk(chunk[0])
#sepration is used here so it can seprate these information

# %%
all_chunks = []
for chunk in chunks:
    
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'intaglobal', 'no_of_followers': 6851.0, 'no_of_following': 262, 'no_of_posts': 1946, 'name': 'INTA', 'types_of_pages': 'Nonprofit organization', 'bio': 'The association of ™ professionals.\ninta.campsite.bio'}, {'username': '_anujsinghal', 'no_of_followers': 681.0, 'no_of_following': 248, 'no_of_posts': 1785, 'name': 'Anuj Singhal', 'types_of_pages': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}, {'username': 'code_flare', 'no_of_followers': 216.0, 'no_of_following': 10, 'no_of_posts': 165, 'name': 'The Journey Notebook | Travel | Food Blogger', 'types_of_pages': 'Blogger', 'bio': '📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a'}, {'username': 'bangalore_tech_bro', 'no_of_followers': 12.5,
# ...

# %%
import json 
s  = json.dumps(all_chunks,indent=4) 
s
# Out:
# '[\n    {\n        "username": "intaglobal",\n        "no_of_followers": 6851.0,\n        "no_of_following": 262,\n        "no_of_posts": 1946,\n        "name": "INTA",\n        "types_of_pages": "Nonprofit organization",\n        "bio": "The association of \\u2122 professionals.\\ninta.campsite.bio"\n    },\n    {\n        "username": "_anujsinghal",\n        "no_of_followers": 681.0,\n        "no_of_following": 248,\n        "no_of_posts": 1785,\n        "name": "Anuj Singhal",\n        "types_of_pages": "Digital creator",\n        "bio": "Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\\nLet\\u2019s talk about finance and life\\nContact: Singhalanuj1010@gmail.com\\nhindi.cnbctv18.com/market-gurukul"\n    },\n    {\n        "username": "code_flare",\n        "no_of_followers": 216.0,\n        "no_of_following": 10,\n        "no_of_posts": 165,\n        "name": "The Journey Notebook | Travel | Food Blogger",\n        "types_of_pages": "Blogger",\n        "
# ...

# %%
max = 0
for chunk in all_chunks:
    if(max<=chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_posts = chunk
chunk_with_max_posts
# Out:
# {'username': 'startuphub_blr',
#  'no_of_followers': 45.0,
#  'no_of_following': 120,
#  'no_of_posts': 2300,
#  'name': 'Startup Hub Bangalore',
#  'types_of_pages': 'Media',
#  'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %%
max = 0
for chunk in all_chunks:
    if(max<=chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk 
chunk_with_max_followers
# Out:
# {'username': 'indiranagar_gossip',
#  'no_of_followers': 8900.0,
#  'no_of_following': 20,
#  'no_of_posts': 300,
#  'name': 'Indiranagar Spy',
#  'types_of_pages': 'Personal Blog',
#  'bio': 'Not just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy'}

# %%
max = 0
for chunk in all_chunks:
    if(max<=chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk 
chunk_with_max_following
# Out:
# {'username': 'katiasales2220',
#  'no_of_followers': 219.0,
#  'no_of_following': 1401,
#  'no_of_posts': 107,
#  'name': 'Katia Sales',
#  'types_of_pages': 'Alfabetização e Reforço Escolar',
#  'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %%
#how many categories

# %%
types_of_catogries = set()
for chunk in all_chunks:
    types_of_catogries.add(chunk['types_of_pages'])

types_of_catogries,len(types_of_catogries)
# Out:
# ({'Alfabetização e Reforço Escolar',
#   'Blogger',
#   'Community',
#   'Digital creator',
#   'Entrepreneur',
#   'Food & Drink',
#   'Gamer',
#   'Investor',
#   'Media',
#   'Nonprofit organization',
#   'Personal Blog',
#   'Public Figure',
#   'unknown'},
#  13)
