# %%
name = "Monu"

# %%
name
# Out:
# 'Monu'

# %%
name.upper
# Out:
# <function str.upper()>

# %%
print(name.upper)
# Out:
# <built-in method upper of str object at 0x0000017537CFF930>

# %%
name.endswith("nu")
# Out:
# True

# %%
name.count("m")
# Out:
# 0

# %%
b = monu verma
# Out:
#   Cell In[7], line 1
#     b = monu verma
#              ^
# SyntaxError: invalid syntax

# %%
print(len(b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(len(b))
#
# NameError: name 'b' is not defined

# %%
b = "monu verma"
print(len(b))
# Out:
# 10

# %%
print[-1:0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print[-1:0]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
print([-1:0])
# Out:
#   Cell In[11], line 1
#     print([-1:0])
#              ^
# SyntaxError: invalid syntax

# %%
print{0:-1]
# Out:
#   Cell In[12], line 1
#     print{0:-1]
#               ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{'

# %%
print [0:-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print [0:-1]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
