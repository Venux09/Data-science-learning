# %%
f=  open("monu.txt"."r")
# Out:
#   Cell In[4], line 1
#     f=  open("monu.txt"."r")
#                         ^
# SyntaxError: invalid syntax

# %%
f = open("conda.txt","w")

# %%
f.write("this is good way of learning and understanding data science")
# Out:
# 59

# %%
f.close()
