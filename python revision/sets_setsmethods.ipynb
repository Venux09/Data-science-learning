# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
b = set(a)

# %%
type(b)
# Out:
# set

# %%
a = {1,4,5,6,2,4,5,6}

# %%
a
# Out:
# {1, 2, 4, 5, 6}

# %%
a
# Out:
# {1, 2, 4, 5, 6}

# %%
a
# Out:
# {1, 2, 4, 5, 6}

# %%
a
# Out:
# {1, 2, 4, 5, 6}

# %%
a = {1,4,5,6,2,4,5,6}

# %%
a.add(34)

# %%
a
# Out:
# {1, 2, 4, 5, 6, 34}

# %%
a.clear()

# %%
a
# Out:
# set()

# %%
a.upadate([4,5,6,7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a.upadate(4,5,6,7)
#
# AttributeError: 'set' object has no attribute 'upadate'

# %%
a
# Out:
# set()

# %%
a.update([1,2,3,4])

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
a.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a.remove(5)
#
# KeyError: 5

# %%
a.discard(5)

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
a.pop()
# Out:
# 1

# %%
b= {12,14,1,55,15,65,24}

# %%
b
# Out:
# {1, 12, 14, 15, 24, 55, 65}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 12, 14, 15, 24, 55, 65}

# %%
if  a.intersection(b):
    print("none")

# %%
a= {1,2,3,4,5}

# %%
b= {2,3,4}

# %%
a.issuperset(b)
# Out:
# True

# %%
b.issubset(a)
# Out:
# True
