# %%
student = {
    "name":"monu",

    
}

# %%
student["name"]
# Out:
# 'monu'

# %%
student.get("name")
# Out:
# 'monu'

# %%
student.get("ananme")

# %%
student["name"]
# Out:
# 'monu'

# %%
student["name"]= "makroni"

# %%
student["name"]
# Out:
# 'makroni'

# %%
student.keys()
# Out:
# dict_keys(['name'])

# %%
student.values
# Out:
# <function dict.values()>

# %%
student.update({"age":"17","language":"python"})

# %%
student
# Out:
# {'name': 'makroni', 'age': '17', 'language': 'python'}
