# %%
code = 404

# %%
match code:
    case  404:
        print("Not found")
# Out:
# Not found

# %%
status-code = 200
# Out:
#   Cell In[3], line 1
#     status-code = 200
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
status_code = 200

# %%
match code:
    case 200:
        print("good response")
        print("good job on working the  server")
    case 404:
        print("Not found")
# Out:
# Not found
