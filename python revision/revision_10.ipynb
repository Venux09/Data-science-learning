# %%
l = ["monu", "monu"]

# %%
l[0]
# Out:
# 'monu'

# %%
l[1]
# Out:
# 'monu'

# %%
l
# Out:
# ['monu', 'monu']

# %%
l.append["1"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l.append["1"]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
m= [1,2,3,4,5,6,7]

# %%
m.append(10)

# %%
m
# Out:
# [1, 2, 3, 4, 5, 6, 7, 10]

# %%
m.insert(3,300)

# %%
m
# Out:
# [1, 2, 3, 300, 4, 5, 6, 7, 10]

# %%
m.index(300)
# Out:
# 3

# %%
m.pop()
# Out:
# 10

# %%
m.sort()

# %%
m
# Out:
# [1, 2, 3, 4, 5, 6, 7, 300]

# %%
m.sorted()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 m.sorted()
#
# AttributeError: 'list' object has no attribute 'sorted'

# %%
m
# Out:
# [1, 2, 3, 4, 5, 6, 7, 300]

# %%
y = [1,2,3,4,5,True,False,"banana",[00+1000]]

# %%
y
# Out:
# [1, 2, 3, 4, 5, True, False, 'banana', [1000]]

# %%
y.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 y.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
n = m+y

# %%
n
# Out:
# [1, 2, 3, 4, 5, 6, 7, 300, False, 1, True, 2, 3, 4, 5, 'banana', [1000]]

# %%
split = "monu-sonu-tonu-ghonu-chonu-londu-ghodu"
split.split()
# Out:
# ['monu-sonu-tonu-ghonu-chonu-londu-ghodu']

# %%
split.split("-")
# Out:
# ['monu', 'sonu', 'tonu', 'ghonu', 'chonu', 'londu', 'ghodu']
