# %%
import json

# %%
obj = {"name":"monu","age":'17'}
s = json.dumps(obj)

# %%
type(s)
# Out:
# str

# %%
s
# Out:
# '{"name": "monu", "age": "17"}'

# %%
d = json.loads('{"name":"monu","age":'17'}')
type(d)
# Out:
#   Cell In[9], line 1
#     d = json.loads('{"name":"monu","age":'17'}')
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
fiel = open("data.json","w")

# %%
json.dump(obj,fiel)

# %%
fiel.close
# Out:
# <function TextIOWrapper.close()>

# %%
fiel.close()

# %%
json_data= '{"name": "Alice", "age": 25, "city": "New York"}'

# %%
type(json_data)
# Out:
# str

# %%
python_data = json.loads(json_data)

# %%
python_data
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
type(python_data)
# Out:
# dict

# %%
formatted_data = json.dumps(json_data,indent=4)

# %%
formatted_data
# Out:
# '"{\\"name\\": \\"Alice\\", \\"age\\": 25, \\"city\\": \\"New York\\"}"'
