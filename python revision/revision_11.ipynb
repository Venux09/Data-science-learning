# %%
t = (2,3,4,5,6,7)

# %%
t
# Out:
# (2, 3, 4, 5, 6, 7)

# %%
t[0]
# Out:
# 2

# %%
t[0:-1]
# Out:
# (2, 3, 4, 5, 6)

# %%
person = ("monu",17,"programmer")

# %%
person
# Out:
# ('monu', 17, 'programmer')

# %%
name,age,profession = person

# %%
name
# Out:
# 'monu'

# %%
age
# Out:
# 17

# %%
progession
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 progession
#
# NameError: name 'progession' is not defined

# %%
profession
# Out:
# 'programmer'
